# %%
import pandas as pd
import os
from openai import OpenAI
from pathlib import Path
import json
from datetime import datetime, date

# %%
print("Starting to gather embeddings... this may take some time")

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "sk-proj-HSrHGyOHtEDtr9loLzRjT3BlbkFJTUFaqCLYDEs3B7qpBz7z"))

fact_check_insights_filepath = Path().cwd().parent.joinpath('data/factchecked_statements/fact_check_insights.json')
# Out:
# Starting to gather embeddings... this may take some time

# %%
with open(fact_check_insights_filepath) as f:
    data = json.load(f)

# %%
media_reviews = data['mediaReviews']

# %%
mr_df = pd.DataFrame(media_reviews)

# %%
mr_df.insert(5, 'rating', mr_df.mediaAuthenticityCategory)

# %%
claim_reviews = data['claimReviews']

# %%
cr_df = pd.DataFrame(claim_reviews)

# %%
cr_df.insert(5, 'rating', cr_df.reviewRating.str['alternateName'])

# %%
cr_df
# Out:
#                                           id            @context        @type  \
# 0       cd8d5cf1-2474-45b9-a7af-b1f825c5ba55  https://schema.org  ClaimReview
# 1       9b847434-dc35-4e15-aa4c-d822eaff1900  https://schema.org  ClaimReview
# 2       e74002af-7ca3-4071-917c-0585430d459d  https://schema.org  ClaimReview
# 3       7fa85432-ef67-4edb-b60c-b3342d39db42  https://schema.org  ClaimReview
# 4       4c323a0f-f67b-4ace-b77e-cf573ff8ba00  https://schema.org  ClaimReview
# ...                                      ...                 ...          ...
# 239805  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da  https://schema.org  ClaimReview
# 239806  898c10ff-db7a-4fc5-aed2-d6e72e95107f  https://schema.org  ClaimReview
# 239807  74d6c667-1663-49cc-b5cd-7f470b7a0006  https://schema.org  ClaimReview
# 239808  c56456ec-a21d-472b-904b-5201c995a3ea  https://schema.org  ClaimReview
# 239809  bdc63515-9536-4bce-8243-c812d0650d0b  https://schema.org  ClaimReview
#
#                                                    author  \
# 0       {'@type': 'Organization', 'name': 'Boatos.org'...
# 1       {'@type': 'Organization', 'name': 'Boatos.org'...
# 2       {'@type': 'Organization', 'name': 'Lupa', 'url...
# 3       {'@type': 'Organization', 'name': 'Deutsche Pr...
# 4       {'@type': 'Organization', 'name': 'dpa-factche...
# ...                                                   ...
# 239805  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239806  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239807  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239808  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239809  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                             claimReviewed  \
# 0       Governo Lula isenta as empresas de recolherem ...
# 1       Veículo do MST envolvido em acidente, carregan...
# 2       Benjamin Netanyahu não atendeu Lula ao telefon...
# 3       Vom 3. November an durfte sich die österreichi...
# 4       Das Video zeigt ein brennendes Polizeiauto in ...
# ...                                                   ...
# 239805  "OVNI en Arlington, Texas, avistado durante el...
# 239806  Photo shows former President Barack Obama wear...
# 239807  "OVNI en Arlington, Texas, avistado durante el...
# 239808  Photo shows former President Barack Obama wear...
# 239809  "OVNI en Arlington, Texas, avistado durante el...
#
#                                                    rating datePublished  \
# 0                                                   Falso    2023-05-22
# 1                                                   Falso    2023-05-22
# 2                                                   Falso    2023-10-19
# 3       Die Sporthilfe-Gala wurde bereits am Nachmitta...    2020-11-19
# 4       Das Video zeigt einen Filmdreh im Jahr 2020 in...    2023-10-19
# ...                                                   ...           ...
# 239805                                              False    2024-04-25
# 239806                                      Pants on Fire    2024-04-25
# 239807                                              False    2024-04-25
# 239808                                      Pants on Fire    2024-04-25
# 239809                                              False    2024-04-25
#
#                                              itemReviewed  \
# 0       {'@type': 'Claim', 'author': {'@type': 'Person...
# 1       {'@type': 'Claim', 'author': {'@type': 'Person...
# 2       {'@type': 'Claim', 'datePublished': '2023-10-1...
# 3       {'@type': 'Claim', 'datePublished': '2020-11-1...
# 4       {'@type': 'Claim', 'datePublished': '2023-10-0...
# ...                                                   ...
# 239805  {'@type': 'CreativeWork', 'datePublished': '20...
# 239806  {'@type': 'CreativeWork', 'datePublished': '20...
# 239807  {'@type': 'CreativeWork', 'datePublished': '20...
# 239808  {'@type': 'CreativeWork', 'datePublished': '20...
# 239809  {'@type': 'CreativeWork', 'datePublished': '20...
#
#                                              reviewRating  \
# 0           {'@type': 'Rating', 'alternateName': 'Falso'}
# 1           {'@type': 'Rating', 'alternateName': 'Falso'}
# 2           {'@type': 'Rating', 'alternateName': 'Falso'}
# 3       {'@type': 'Rating', 'alternateName': 'Die Spor...
# 4       {'@type': 'Rating', 'alternateName': 'Das Vide...
# ...                                                   ...
# 239805  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
# 239806  {'@type': 'Rating', 'ratingExplanation': 'This...
# 239807  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
# 239808  {'@type': 'Rating', 'ratingExplanation': 'This...
# 239809  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
#
#                                                       url
# 0       https://www.boatos.org/politica/lula-isenta-em...
# 1       https://www.boatos.org/politica/veiculo-mst-ch...
# 2       https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 3       https://dpa-factchecking.com/austria/200921-99...
# 4       https://dpa-factchecking.com/germany/231017-99...
# ...                                                   ...
# 239805  https://www.politifact.com/factchecks/2024/apr...
# 239806  https://www.politifact.com/factchecks/2024/apr...
# 239807  https://www.politifact.com/factchecks/2024/apr...
# 239808  https://www.politifact.com/factchecks/2024/apr...
# 239809  https://www.politifact.com/factchecks/2024/apr...
#
# [239810 rows x 10 columns]

# %%
fact_check_insights = pd.concat([cr_df, mr_df])

# %%
fact_check_insights
# Out:
#                                         id            @context        @type  \
# 0     cd8d5cf1-2474-45b9-a7af-b1f825c5ba55  https://schema.org  ClaimReview
# 1     9b847434-dc35-4e15-aa4c-d822eaff1900  https://schema.org  ClaimReview
# 2     e74002af-7ca3-4071-917c-0585430d459d  https://schema.org  ClaimReview
# 3     7fa85432-ef67-4edb-b60c-b3342d39db42  https://schema.org  ClaimReview
# 4     4c323a0f-f67b-4ace-b77e-cf573ff8ba00  https://schema.org  ClaimReview
# ...                                    ...                 ...          ...
# 1379  429b670a-3e09-41f1-80b6-f5b9891a33e2  https://schema.org  MediaReview
# 1380  6f83d73e-6e25-4f91-9e48-b5e4d0310e5e  https://schema.org  MediaReview
# 1381  97366399-d629-4b76-b27c-0c7e850a5017  https://schema.org  MediaReview
# 1382  67c76978-b817-49cc-bd6f-1732443c83c6  https://schema.org  MediaReview
# 1383  0fe5d685-e533-455f-80be-bc8238a614c0  https://schema.org  MediaReview
#
#                                                  author  \
# 0     {'@type': 'Organization', 'name': 'Boatos.org'...
# 1     {'@type': 'Organization', 'name': 'Boatos.org'...
# 2     {'@type': 'Organization', 'name': 'Lupa', 'url...
# 3     {'@type': 'Organization', 'name': 'Deutsche Pr...
# 4     {'@type': 'Organization', 'name': 'dpa-factche...
# ...                                                 ...
# 1379  {'@type': 'Organization', 'name': 'PolitiFact'...
# 1380  {'@type': 'Organization', 'name': 'PolitiFact'...
# 1381  {'@type': 'Organization', 'name': 'PolitiFact'...
# 1382  {'@type': 'Organization', 'name': 'PolitiFact'...
# 1383  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                           claimReviewed  \
# 0     Governo Lula isenta as empresas de recolherem ...
# 1     Veículo do MST envolvido em acidente, carregan...
# 2     Benjamin Netanyahu não atendeu Lula ao telefon...
# 3     Vom 3. November an durfte sich die österreichi...
# 4     Das Video zeigt ein brennendes Polizeiauto in ...
# ...                                                 ...
# 1379                                                NaN
# 1380                                                NaN
# 1381                                                NaN
# 1382                                                NaN
# 1383                                                NaN
#
#                                                  rating datePublished  \
# 0                                                 Falso    2023-05-22
# 1                                                 Falso    2023-05-22
# 2                                                 Falso    2023-10-19
# 3     Die Sporthilfe-Gala wurde bereits am Nachmitta...    2020-11-19
# 4     Das Video zeigt einen Filmdreh im Jahr 2020 in...    2023-10-19
# ...                                                 ...           ...
# 1379                                    Missing Context    2021-03-22
# 1380                                    Missing Context    2021-03-05
# 1381                                        Transformed    2020-10-02
# 1382                                    Missing Context    2020-09-18
# 1383                                           Original    2022-09-15
#
#                                            itemReviewed  \
# 0     {'@type': 'Claim', 'author': {'@type': 'Person...
# 1     {'@type': 'Claim', 'author': {'@type': 'Person...
# 2     {'@type': 'Claim', 'datePublished': '2023-10-1...
# 3     {'@type': 'Claim', 'datePublished': '2020-11-1...
# 4     {'@type': 'Claim', 'datePublished': '2023-10-0...
# ...                                                 ...
# 1379  {'contentUrl': 'https://www.facebook.com/Bamil...
# 1380  {'contentUrl': 'https://www.instagram.com/p/CL...
# 1381  {'contentUrl': 'https://twitter.com/iMajorWish...
# 1382  {'contentUrl': 'https://www.facebook.com/38172...
# 1383  {'contentUrl': 'https://web.archive.org/web/20...
#
#                                            reviewRating  \
# 0         {'@type': 'Rating', 'alternateName': 'Falso'}
# 1         {'@type': 'Rating', 'alternateName': 'Falso'}
# 2         {'@type': 'Rating', 'alternateName': 'Falso'}
# 3     {'@type': 'Rating', 'alternateName': 'Die Spor...
# 4     {'@type': 'Rating', 'alternateName': 'Das Vide...
# ...                                                 ...
# 1379                                                NaN
# 1380                                                NaN
# 1381                                                NaN
# 1382                                                NaN
# 1383                                                NaN
#
#                                                     url  \
# 0     https://www.boatos.org/politica/lula-isenta-em...
# 1     https://www.boatos.org/politica/veiculo-mst-ch...
# 2     https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 3     https://dpa-factchecking.com/austria/200921-99...
# 4     https://dpa-factchecking.com/germany/231017-99...
# ...                                                 ...
# 1379  https://www.politifact.com/factchecks/2021/mar...
# 1380  https://www.politifact.com/factchecks/2021/mar...
# 1381  https://www.politifact.com/factchecks/2020/oct...
# 1382  https://www.politifact.com/factchecks/2020/sep...
# 1383  https://www.politifact.com/factchecks/2022/aug...
#
#      mediaAuthenticityCategory originalMediaContextDescription  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 1379           Missing Context
# 1380           Missing Context
# 1381               Transformed
# 1382           Missing Context
# 1383                  Original                  It is a meme.
#
#                                       originalMediaLink
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1379
# 1380
# 1381
# 1382
# 1383  https://web.archive.org/web/20220829153907/htt...
#
# [241194 rows x 13 columns]

# %%
rating_values = fact_check_insights['rating'].value_counts()

# %%
rating_values.to_csv('rating_values')

# %%
rating_values = fact_check_insights.rating.unique()

# %%
(rating_values)
# Out:
# array(['Falso',
#        'Die Sporthilfe-Gala wurde bereits am Nachmittag des 10. Novembers abgehalten und aufgezeichnet. Corona-Regeln wurden laut den Veranstaltern eingehalten.',
#        'Das Video zeigt einen Filmdreh im Jahr 2020 in Nordirland.', ...,
#        'Satire/Parody, Original', 'Transformed, Staged',
#        'Cropped, Satire/Parody'], dtype=object)

# %%
fact_check_insights_false = fact_check_insights[(fact_check_insights['rating'] == "false") | 
                                                               (fact_check_insights['rating'] == "pants-fire") | 
                                                               (fact_check_insights['rating'] == "Falso") |
                                                               (fact_check_insights['rating'] == "False") |
                                                               (fact_check_insights['rating'] == "FALSE") |
                                                               (fact_check_insights['rating'] == "Notizia falsa") |
                                                               (fact_check_insights['rating'] == "Fake") |
                                                               (fact_check_insights['rating'] == "Pants on Fire") |
                                                               (fact_check_insights['rating'] == "falso") |
                                                               (fact_check_insights['rating'] == "Falso!")
                                                               ]

# %%
fact_check_insights_false
# Out:
#                                           id            @context        @type  \
# 0       cd8d5cf1-2474-45b9-a7af-b1f825c5ba55  https://schema.org  ClaimReview
# 1       9b847434-dc35-4e15-aa4c-d822eaff1900  https://schema.org  ClaimReview
# 2       e74002af-7ca3-4071-917c-0585430d459d  https://schema.org  ClaimReview
# 9       64dc0acd-92c7-45fb-9255-2a5ff85cc2da  https://schema.org  ClaimReview
# 10      3f52fcf6-3825-4c32-b6aa-854655e70128  https://schema.org  ClaimReview
# ...                                      ...                 ...          ...
# 239805  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da  https://schema.org  ClaimReview
# 239806  898c10ff-db7a-4fc5-aed2-d6e72e95107f  https://schema.org  ClaimReview
# 239807  74d6c667-1663-49cc-b5cd-7f470b7a0006  https://schema.org  ClaimReview
# 239808  c56456ec-a21d-472b-904b-5201c995a3ea  https://schema.org  ClaimReview
# 239809  bdc63515-9536-4bce-8243-c812d0650d0b  https://schema.org  ClaimReview
#
#                                                    author  \
# 0       {'@type': 'Organization', 'name': 'Boatos.org'...
# 1       {'@type': 'Organization', 'name': 'Boatos.org'...
# 2       {'@type': 'Organization', 'name': 'Lupa', 'url...
# 9       {'@type': 'Organization', 'name': 'Boatos.org'...
# 10      {'@type': 'Organization', 'name': 'Lupa', 'url...
# ...                                                   ...
# 239805  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239806  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239807  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239808  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239809  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                             claimReviewed         rating  \
# 0       Governo Lula isenta as empresas de recolherem ...          Falso
# 1       Veículo do MST envolvido em acidente, carregan...          Falso
# 2       Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 9       LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 10      Líder palestino defende Israel na ONU e deixa ...          Falso
# ...                                                   ...            ...
# 239805  "OVNI en Arlington, Texas, avistado durante el...          False
# 239806  Photo shows former President Barack Obama wear...  Pants on Fire
# 239807  "OVNI en Arlington, Texas, avistado durante el...          False
# 239808  Photo shows former President Barack Obama wear...  Pants on Fire
# 239809  "OVNI en Arlington, Texas, avistado durante el...          False
#
#        datePublished                                       itemReviewed  \
# 0         2023-05-22  {'@type': 'Claim', 'author': {'@type': 'Person...
# 1         2023-05-22  {'@type': 'Claim', 'author': {'@type': 'Person...
# 2         2023-10-19  {'@type': 'Claim', 'datePublished': '2023-10-1...
# 9         2023-10-19  {'@type': 'Claim', 'author': {'@type': 'Person...
# 10        2023-10-23  {'@type': 'Claim', 'author': {'@type': 'Person...
# ...              ...                                                ...
# 239805    2024-04-25  {'@type': 'CreativeWork', 'datePublished': '20...
# 239806    2024-04-25  {'@type': 'CreativeWork', 'datePublished': '20...
# 239807    2024-04-25  {'@type': 'CreativeWork', 'datePublished': '20...
# 239808    2024-04-25  {'@type': 'CreativeWork', 'datePublished': '20...
# 239809    2024-04-25  {'@type': 'CreativeWork', 'datePublished': '20...
#
#                                              reviewRating  \
# 0           {'@type': 'Rating', 'alternateName': 'Falso'}
# 1           {'@type': 'Rating', 'alternateName': 'Falso'}
# 2           {'@type': 'Rating', 'alternateName': 'Falso'}
# 9           {'@type': 'Rating', 'alternateName': 'Falso'}
# 10          {'@type': 'Rating', 'alternateName': 'Falso'}
# ...                                                   ...
# 239805  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
# 239806  {'@type': 'Rating', 'ratingExplanation': 'This...
# 239807  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
# 239808  {'@type': 'Rating', 'ratingExplanation': 'This...
# 239809  {'@type': 'Rating', 'ratingExplanation': 'Lo q...
#
#                                                       url  \
# 0       https://www.boatos.org/politica/lula-isenta-em...
# 1       https://www.boatos.org/politica/veiculo-mst-ch...
# 2       https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 9       https://www.boatos.org/politica/lula-aprovou-a...
# 10      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# ...                                                   ...
# 239805  https://www.politifact.com/factchecks/2024/apr...
# 239806  https://www.politifact.com/factchecks/2024/apr...
# 239807  https://www.politifact.com/factchecks/2024/apr...
# 239808  https://www.politifact.com/factchecks/2024/apr...
# 239809  https://www.politifact.com/factchecks/2024/apr...
#
#        mediaAuthenticityCategory originalMediaContextDescription  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 9                            NaN                             NaN
# 10                           NaN                             NaN
# ...                          ...                             ...
# 239805                       NaN                             NaN
# 239806                       NaN                             NaN
# 239807                       NaN                             NaN
# 239808                       NaN                             NaN
# 239809                       NaN                             NaN
#
#        originalMediaLink
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 9                    NaN
# 10                   NaN
# ...                  ...
# 239805               NaN
# 239806               NaN
# 239807               NaN
# 239808               NaN
# 239809               NaN
#
# [95044 rows x 13 columns]

# %%
fact_check_insights_false.dropna(subset='claimReviewed', inplace=True)
# Out:
# /tmp/ipykernel_48464/3421200345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_check_insights_false.dropna(subset='claimReviewed', inplace=True)

# %%
fact_check_insights_false.isnull().sum()
# Out:
# id                                     0
# @context                               0
# @type                                  0
# author                                 0
# claimReviewed                          0
# rating                                 0
# datePublished                          0
# itemReviewed                           0
# reviewRating                           0
# url                                    0
# mediaAuthenticityCategory          94944
# originalMediaContextDescription    94944
# originalMediaLink                  94944
# dtype: int64

# %%
false_text_df = fact_check_insights_false.drop(columns=['@context', '@type', 'itemReviewed', 'reviewRating', 'mediaAuthenticityCategory', 'originalMediaContextDescription', 'originalMediaLink'])

# %%
# remove entries without publication date

false_text_df = false_text_df[false_text_df['datePublished'] != '']

# %%
false_text_df = false_text_df[false_text_df['datePublished'].str.len() == 10]

# %%
false_text_df = false_text_df.rename(columns={'claimReviewed': 'statement'})

# %%
false_text_df = false_text_df[false_text_df['statement'] != '']

# %%
false_text_df['statement'] = false_text_df['statement'].str.replace('\n', '').replace("'","").replace('"','').replace('“','').replace(',','\,')

# %%
false_text_df.sort_values('datePublished', ascending=False)
# Out:
#                                           id  \
# 99576   0929bd1a-f99d-4903-b632-94840b77bc4a
# 72524   c820c939-b22f-419f-9634-e27ff8c8f450
# 239783  3a62e98e-ebbf-4815-85b6-15889c7de4c6
# 96169   46cf3735-efe4-419a-8c41-05ed35052e2d
# 239794  e5a569b9-942a-4d59-b0aa-23dbd2d8b444
# ...                                      ...
# 231301  544346bb-f150-4ea3-a333-ee18355d9b4b
# 231299  7bf296d2-9c80-475e-812f-90a0d6d78a4d
# 154468  7fd62009-9da4-4f84-a172-7d46ec61e6b9
# 117281  5f853bba-e232-4e83-9569-69d244c422f2
# 178988  ee11acda-3e35-4081-9242-0c3dee33991e
#
#                                                    author  \
# 99576   {'@type': 'Organization', 'name': 'Logically F...
# 72524   {'@type': 'Organization', 'name': 'Fast Check ...
# 239783  {'@type': 'Organization', 'name': 'FACTLY', 'u...
# 96169   {'@type': 'Organization', 'name': 'Vera Files'...
# 239794  {'@type': 'Organization', 'name': 'PolitiFact'...
# ...                                                   ...
# 231301  {'@type': 'Organization', 'url': 'https://www....
# 231299  {'@type': 'Organization', 'url': 'https://www....
# 154468  {'@type': 'Organization', 'url': 'https://www....
# 117281  {'@type': 'Organization', 'url': 'https://www....
# 178988  {'@type': 'Organization', 'name': 'Newschecker...
#
#                                                 statement rating  \
# 99576   A pre-poll survey conducted by Sri Atmasakshi ...   Fake
# 72524   (Video) “Ángulo alternativo en el colapso del ...  Falso
# 239783  The bridge seen in this viral photograph is in...  FALSE
# 96169   China has shown a contract of former president...  False
# 239794  Document shows “Stormy Daniels exonerated Trum...  False
# ...                                                   ...    ...
# 231301  Walt Disney was an illegitimate child, born ou...  False
# 231299  Disney arranged to have himself frozen in cryo...  False
# 154468  Charles Manson was one of the 437 applicants w...  False
# 117281  Charles Manson was one of the 437 applicants w...  False
# 178988  जम्मू-काश्मीरमध्ये कालवा तयार करत असताना सोन्य...  False
#
#        datePublished                                                url
# 99576     2024-04-29  https://www.logicallyfacts.com/en/fact-check/f...
# 72524     2024-04-27  https://www.fastcheck.cl/2024/03/27/video-angu...
# 239783    2024-04-26  https://factly.in/the-bridge-in-this-photo-is-...
# 96169     2024-04-26  https://verafiles.org/articles/vera-files-fact...
# 239794    2024-04-25  https://www.politifact.com/factchecks/2024/apr...
# ...              ...                                                ...
# 231301    1996-07-29  https://www.snopes.com/fact-check/walt-disneys...
# 231299    1995-10-19  https://www.snopes.com/fact-check/suspended-an...
# 154468    1995-09-24  https://www.snopes.com/fact-check/the-music-ma...
# 117281    1995-09-24  https://www.snopes.com/fact-check/the-music-ma...
# 178988    1970-01-01  https://newschecker.in/mr/uncategorized-mr/%25...
#
# [86930 rows x 6 columns]

# %%
false_text_df['statement'].to_list()[40:60]
# Out:
# ['Dia Nacional do Estupro de Tik Tok, 24 de abril de 2021 Desafio assustador do Tik Tok quer promover a prática de abusos',
#  'O AGIR DE DEUS.. Motoboy teve moto apreendida, recebeu água na face, doou lanche a um pai e seu filho que catava lixo para comer e final se torna SURPREENDENTE',
#  'নারায়নগঞ্জের এক যুবলীগ নেত্রীর সঙ্গে মদপান ও অশ্লীল নাচে মত্ত থানার ওসি নন্দকিশোর',
#  'পবিত্র রমজান মাস উপলক্ষে মহামান্য রাষ্ট্রপতির নির্দেশে সরকার সবার বিকাশ একাউন্টে ৫,০০০ টাকা উপহার দিচ্ছে',
#  'JBS Foods International Prezados clientes e amigos: A partir de hoje estaremos atendendo em nossa nova sede nos EUA. A antiga Friboi do grupo JBS passa a se chamar JBS Foods International.',
#  'FACT CHECK: රාවණා රජු සමයේ භාවිතා වූ සන්නිවේදන උපකරණ?',
#  'মামুনুল হক কে গ্রেফতারের প্রতিবাদে লন্ডনে বিক্ষোভ মিছিল',
#  'Mike Yeadon, ex-cientista-chefe da Pfizer: “É tarde demais para salvar alguém que foi injetado com qualquer vacina Covid-19 para aqueles que ainda não foram injetados com o composto mortal',
#  '"Em 100% dos casamentos em Portugal, 94% dá em divórcio".',
#  'Between January 2017 and March 2018, Diahann Carroll publicly praised and defended President Donald Trump and pleaded with Democrats to end their criticism of him. ',
#  'கர்நாடக மாநிலம் ஹுல்லேனஹள்ளியில் பேருந்தின் ஜன்னல் வழி ஏறிய பெண்ணின் கை துண்டானது. இலவச பேருந்து பயணத்தின் விலை தான் உங்கள் கை.. ',
#  'Manny Pacquiao is providing "help" by giving money to people who send their name, address and contact details to the Facebook page Manny Pacquiao Tulong sa Bayang Mahirap. Some posts claim he is giving away P30,000 to P50,000',
#  '“CNN Get Caught Faking an Attack From Hamas in Israel.”',
#  'La misma niña siria en tres bombardeos, manipulación o montaje',
#  'Cristiano Ronaldo posó para una foto con una camiseta del Pacto Histórico',
#  'Una foto muestra a Gustavo Petro junto a Jesús Santrich',
#  'Todo el llano contra el narcotrá-Fico, dice valla publicitaria en Colombia',
#  'Una valla publicitaria de Federico Gutiérrez apareció en Times Square',
#  'Photos showing the “Largest Display of Origami Heart” on display at Angkor Wat were posted on a Facebook page recently. This comes after the Union of Youth Federations of Cambodia (UYFC) aims to make millions of origami hearts to break the Guinness World Record. The above photos were reacted to with mixed comments and shared by many Facebook users who speak Khmer. However, after checking the reliable sources, it proves that the above photos were false.',
#  'Photo of PM Narendra Modi bowing with folded hands to Mukesh Ambani’s wife Nita Ambani']

# %%
# filter out entries older than one year

todays_date = date.today()

# %%
todays_date
# Out:
# datetime.date(2024, 6, 2)

# %%
date.fromisoformat(false_text_df['datePublished'][0])
# Out:
# datetime.date(2023, 5, 22)

# %%
len(false_text_df['datePublished'][0])
# Out:
# 10

# %%
false_text_df['datePublished'][0]
# Out:
# '2023-05-22'

# %%
false_text_df.insert(5, 'reformated_date', false_text_df['datePublished'].apply(lambda x: date.fromisoformat(x)))

# %%
false_text_df
# Out:
#                                           id  \
# 0       cd8d5cf1-2474-45b9-a7af-b1f825c5ba55
# 1       9b847434-dc35-4e15-aa4c-d822eaff1900
# 2       e74002af-7ca3-4071-917c-0585430d459d
# 9       64dc0acd-92c7-45fb-9255-2a5ff85cc2da
# 10      3f52fcf6-3825-4c32-b6aa-854655e70128
# ...                                      ...
# 239805  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da
# 239806  898c10ff-db7a-4fc5-aed2-d6e72e95107f
# 239807  74d6c667-1663-49cc-b5cd-7f470b7a0006
# 239808  c56456ec-a21d-472b-904b-5201c995a3ea
# 239809  bdc63515-9536-4bce-8243-c812d0650d0b
#
#                                                    author  \
# 0       {'@type': 'Organization', 'name': 'Boatos.org'...
# 1       {'@type': 'Organization', 'name': 'Boatos.org'...
# 2       {'@type': 'Organization', 'name': 'Lupa', 'url...
# 9       {'@type': 'Organization', 'name': 'Boatos.org'...
# 10      {'@type': 'Organization', 'name': 'Lupa', 'url...
# ...                                                   ...
# 239805  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239806  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239807  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239808  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239809  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                                 statement         rating  \
# 0       Governo Lula isenta as empresas de recolherem ...          Falso
# 1       Veículo do MST envolvido em acidente, carregan...          Falso
# 2       Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 9       LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 10      Líder palestino defende Israel na ONU e deixa ...          Falso
# ...                                                   ...            ...
# 239805  "OVNI en Arlington, Texas, avistado durante el...          False
# 239806  Photo shows former President Barack Obama wear...  Pants on Fire
# 239807  "OVNI en Arlington, Texas, avistado durante el...          False
# 239808  Photo shows former President Barack Obama wear...  Pants on Fire
# 239809  "OVNI en Arlington, Texas, avistado durante el...          False
#
#        datePublished reformated_date  \
# 0         2023-05-22      2023-05-22
# 1         2023-05-22      2023-05-22
# 2         2023-10-19      2023-10-19
# 9         2023-10-19      2023-10-19
# 10        2023-10-23      2023-10-23
# ...              ...             ...
# 239805    2024-04-25      2024-04-25
# 239806    2024-04-25      2024-04-25
# 239807    2024-04-25      2024-04-25
# 239808    2024-04-25      2024-04-25
# 239809    2024-04-25      2024-04-25
#
#                                                       url
# 0       https://www.boatos.org/politica/lula-isenta-em...
# 1       https://www.boatos.org/politica/veiculo-mst-ch...
# 2       https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 9       https://www.boatos.org/politica/lula-aprovou-a...
# 10      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# ...                                                   ...
# 239805  https://www.politifact.com/factchecks/2024/apr...
# 239806  https://www.politifact.com/factchecks/2024/apr...
# 239807  https://www.politifact.com/factchecks/2024/apr...
# 239808  https://www.politifact.com/factchecks/2024/apr...
# 239809  https://www.politifact.com/factchecks/2024/apr...
#
# [86930 rows x 7 columns]

# %%
false_text_df['time_since_publication'] = todays_date - false_text_df['reformated_date']

# %%
false_text_df.head(3)
# Out:
#                                      id  \
# 0  cd8d5cf1-2474-45b9-a7af-b1f825c5ba55
# 1  9b847434-dc35-4e15-aa4c-d822eaff1900
# 2  e74002af-7ca3-4071-917c-0585430d459d
#
#                                               author  \
# 0  {'@type': 'Organization', 'name': 'Boatos.org'...
# 1  {'@type': 'Organization', 'name': 'Boatos.org'...
# 2  {'@type': 'Organization', 'name': 'Lupa', 'url...
#
#                                            statement rating datePublished  \
# 0  Governo Lula isenta as empresas de recolherem ...  Falso    2023-05-22
# 1  Veículo do MST envolvido em acidente, carregan...  Falso    2023-05-22
# 2  Benjamin Netanyahu não atendeu Lula ao telefon...  Falso    2023-10-19
#
#   reformated_date                                                url  \
# 0      2023-05-22  https://www.boatos.org/politica/lula-isenta-em...
# 1      2023-05-22  https://www.boatos.org/politica/veiculo-mst-ch...
# 2      2023-10-19  https://lupa.uol.com.br/jornalismo/2023/10/19/...
#
#   time_since_publication
# 0      377 days, 0:00:00
# 1      377 days, 0:00:00
# 2      227 days, 0:00:00

# %%
false_text_df.insert(5, 'days_since_publication', false_text_df['time_since_publication'].apply(lambda x: x.days))

# %%
type(false_text_df.days_since_publication)
# Out:
# pandas.core.series.Series

# %%
false_text_df.head(3)
# Out:
#                                      id  \
# 0  cd8d5cf1-2474-45b9-a7af-b1f825c5ba55
# 1  9b847434-dc35-4e15-aa4c-d822eaff1900
# 2  e74002af-7ca3-4071-917c-0585430d459d
#
#                                               author  \
# 0  {'@type': 'Organization', 'name': 'Boatos.org'...
# 1  {'@type': 'Organization', 'name': 'Boatos.org'...
# 2  {'@type': 'Organization', 'name': 'Lupa', 'url...
#
#                                            statement rating datePublished  \
# 0  Governo Lula isenta as empresas de recolherem ...  Falso    2023-05-22
# 1  Veículo do MST envolvido em acidente, carregan...  Falso    2023-05-22
# 2  Benjamin Netanyahu não atendeu Lula ao telefon...  Falso    2023-10-19
#
#    days_since_publication reformated_date  \
# 0                     377      2023-05-22
# 1                     377      2023-05-22
# 2                     227      2023-10-19
#
#                                                  url time_since_publication
# 0  https://www.boatos.org/politica/lula-isenta-em...      377 days, 0:00:00
# 1  https://www.boatos.org/politica/veiculo-mst-ch...      377 days, 0:00:00
# 2  https://lupa.uol.com.br/jornalismo/2023/10/19/...      227 days, 0:00:00

# %%
year_to_date_false_text_df = false_text_df[false_text_df['days_since_publication'] <= 365]

# %%
year_to_date_false_text_df
# Out:
#                                           id  \
# 2       e74002af-7ca3-4071-917c-0585430d459d
# 9       64dc0acd-92c7-45fb-9255-2a5ff85cc2da
# 10      3f52fcf6-3825-4c32-b6aa-854655e70128
# 21      f953a13b-efbe-4963-84fa-c544738fb401
# 22      64dddcbd-2444-41af-8269-de7e09d3257d
# ...                                      ...
# 239805  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da
# 239806  898c10ff-db7a-4fc5-aed2-d6e72e95107f
# 239807  74d6c667-1663-49cc-b5cd-7f470b7a0006
# 239808  c56456ec-a21d-472b-904b-5201c995a3ea
# 239809  bdc63515-9536-4bce-8243-c812d0650d0b
#
#                                                    author  \
# 2       {'@type': 'Organization', 'name': 'Lupa', 'url...
# 9       {'@type': 'Organization', 'name': 'Boatos.org'...
# 10      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 21      {'@type': 'Organization', 'name': 'Boatos.org'...
# 22      {'@type': 'Organization', 'name': 'Boatos.org'...
# ...                                                   ...
# 239805  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239806  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239807  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239808  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239809  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                                 statement         rating  \
# 2       Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 9       LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 10      Líder palestino defende Israel na ONU e deixa ...          Falso
# 21      Após falência no Brasil, Pernambucanas se vê c...          Falso
# 22      Líder do Hamas, com Haddad e Gleise,Aliados?vo...          Falso
# ...                                                   ...            ...
# 239805  "OVNI en Arlington, Texas, avistado durante el...          False
# 239806  Photo shows former President Barack Obama wear...  Pants on Fire
# 239807  "OVNI en Arlington, Texas, avistado durante el...          False
# 239808  Photo shows former President Barack Obama wear...  Pants on Fire
# 239809  "OVNI en Arlington, Texas, avistado durante el...          False
#
#        datePublished  days_since_publication reformated_date  \
# 2         2023-10-19                     227      2023-10-19
# 9         2023-10-19                     227      2023-10-19
# 10        2023-10-23                     223      2023-10-23
# 21        2023-10-23                     223      2023-10-23
# 22        2023-10-19                     227      2023-10-19
# ...              ...                     ...             ...
# 239805    2024-04-25                      38      2024-04-25
# 239806    2024-04-25                      38      2024-04-25
# 239807    2024-04-25                      38      2024-04-25
# 239808    2024-04-25                      38      2024-04-25
# 239809    2024-04-25                      38      2024-04-25
#
#                                                       url  \
# 2       https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 9       https://www.boatos.org/politica/lula-aprovou-a...
# 10      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# 21      https://www.boatos.org/tecnologia/pernambucana...
# 22      https://www.boatos.org/politica/haddad-gleisi-...
# ...                                                   ...
# 239805  https://www.politifact.com/factchecks/2024/apr...
# 239806  https://www.politifact.com/factchecks/2024/apr...
# 239807  https://www.politifact.com/factchecks/2024/apr...
# 239808  https://www.politifact.com/factchecks/2024/apr...
# 239809  https://www.politifact.com/factchecks/2024/apr...
#
#        time_since_publication
# 2           227 days, 0:00:00
# 9           227 days, 0:00:00
# 10          223 days, 0:00:00
# 21          223 days, 0:00:00
# 22          227 days, 0:00:00
# ...                       ...
# 239805       38 days, 0:00:00
# 239806       38 days, 0:00:00
# 239807       38 days, 0:00:00
# 239808       38 days, 0:00:00
# 239809       38 days, 0:00:00
#
# [16029 rows x 9 columns]

# %%
len(year_to_date_false_text_df)
# Out:
# 16029

# %%
claim_review_list = year_to_date_false_text_df['statement'].to_list()

# %%
# trying initial non-loop version again

def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

year_to_date_false_text_df['statement_embedding'] = year_to_date_false_text_df['statement'].apply(lambda x: get_embedding(x, model='text-embedding-3-small'))
embedded_false_statements_path = Path().cwd().parent.joinpath('data/factchecked_statements/embedded_false_statements.csv')
false_text_df.to_csv(embedded_false_statements_path, index=False)

# %% [markdown]
# If it works better than the loop version, end here and replace code in .py script. Maybe come back sometime and try to make the loop work.

# %%
# sorted version - still not good
'''

embeddings_list_sorted = []
counter = 0
failed_embeddings = 0
total_rows = len(year_to_date_false_text_df)

for claim in sorted(claim_review_list):
    try:
        result = client.embeddings.create(input = [claim], model="text-embedding-3-small").data[0].embedding
        print_text = f"Embedded statement {counter} of {total_rows}. [{int((counter / total_rows * 100))}%]          "
        print("\r", print_text, end="")
    except:
        result = 'embedding failed'
        failed_embeddings += 1
        error_print_text = f"Embedding failed for statement {counter} of {total_rows}"
        print(error_print_text)
    counter += 1
    embeddings_list_sorted.append(result)

'''
# Out:
#  Embedded statement 16028 of 16029. [99%]

# %%
# first version with loop - not good
'''


embeddings_list = []
counter = 0
failed_embeddings = 0
total_rows = len(year_to_date_false_text_df)

for claim in claim_review_list:
    try:
        result = client.embeddings.create(input = [claim], model="text-embedding-3-small").data[0].embedding
        print_text = f"Embedded statement {counter} of {total_rows}. [{int((counter / total_rows * 100))}%]          "
        print("\r", print_text, end="")
    except:
        result = 'embedding failed'
        failed_embeddings += 1
        error_print_text = f"Embedding failed for statement {counter} of {total_rows}"
        print(error_print_text)
    counter += 1
    embeddings_list.append(result)

'''
# Out:
#  Embedded statement 51 of 16029. [0%]          Embedding failed for statement 52 of 16029
#  Embedded statement 128 of 16029. [0%]

# %%
# year_to_date_false_text_df['statement_embedding'] = year_to_date_false_text_df['claimReviewed'].apply(lambda x: get_embedding(x, model='text-embedding-3-small'))

year_to_date_false_text_df['statement_embedding'] = embeddings_list

embedded_false_statements_path = Path().cwd().parent.joinpath('data/factchecked_statements/embedded_false_statements.csv')

# %%
year_to_date_false_text_df.to_csv(embedded_false_statements_path, index=False)

# %%
year_to_date_false_text_df
# Out:
#                                           id  \
# 2       e74002af-7ca3-4071-917c-0585430d459d
# 9       64dc0acd-92c7-45fb-9255-2a5ff85cc2da
# 10      3f52fcf6-3825-4c32-b6aa-854655e70128
# 21      f953a13b-efbe-4963-84fa-c544738fb401
# 22      64dddcbd-2444-41af-8269-de7e09d3257d
# ...                                      ...
# 239805  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da
# 239806  898c10ff-db7a-4fc5-aed2-d6e72e95107f
# 239807  74d6c667-1663-49cc-b5cd-7f470b7a0006
# 239808  c56456ec-a21d-472b-904b-5201c995a3ea
# 239809  bdc63515-9536-4bce-8243-c812d0650d0b
#
#                                                    author  \
# 2       {'@type': 'Organization', 'name': 'Lupa', 'url...
# 9       {'@type': 'Organization', 'name': 'Boatos.org'...
# 10      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 21      {'@type': 'Organization', 'name': 'Boatos.org'...
# 22      {'@type': 'Organization', 'name': 'Boatos.org'...
# ...                                                   ...
# 239805  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239806  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239807  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239808  {'@type': 'Organization', 'name': 'PolitiFact'...
# 239809  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                             claimReviewed         rating  \
# 2       Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 9       LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 10      Líder palestino defende Israel na ONU e deixa ...          Falso
# 21      Após falência no Brasil, Pernambucanas se vê c...          Falso
# 22      Líder do Hamas, com Haddad e Gleise,Aliados?vo...          Falso
# ...                                                   ...            ...
# 239805  "OVNI en Arlington, Texas, avistado durante el...          False
# 239806  Photo shows former President Barack Obama wear...  Pants on Fire
# 239807  "OVNI en Arlington, Texas, avistado durante el...          False
# 239808  Photo shows former President Barack Obama wear...  Pants on Fire
# 239809  "OVNI en Arlington, Texas, avistado durante el...          False
#
#        datePublished  days_since_publication reformated_date  \
# 2         2023-10-19                     226      2023-10-19
# 9         2023-10-19                     226      2023-10-19
# 10        2023-10-23                     222      2023-10-23
# 21        2023-10-23                     222      2023-10-23
# 22        2023-10-19                     226      2023-10-19
# ...              ...                     ...             ...
# 239805    2024-04-25                      37      2024-04-25
# 239806    2024-04-25                      37      2024-04-25
# 239807    2024-04-25                      37      2024-04-25
# 239808    2024-04-25                      37      2024-04-25
# 239809    2024-04-25                      37      2024-04-25
#
#                                                       url  \
# 2       https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 9       https://www.boatos.org/politica/lula-aprovou-a...
# 10      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# 21      https://www.boatos.org/tecnologia/pernambucana...
# 22      https://www.boatos.org/politica/haddad-gleisi-...
# ...                                                   ...
# 239805  https://www.politifact.com/factchecks/2024/apr...
# 239806  https://www.politifact.com/factchecks/2024/apr...
# 239807  https://www.politifact.com/factchecks/2024/apr...
# 239808  https://www.politifact.com/factchecks/2024/apr...
# 239809  https://www.politifact.com/factchecks/2024/apr...
#
#        time_since_publication
# 2           226 days, 0:00:00
# 9           226 days, 0:00:00
# 10          222 days, 0:00:00
# 21          222 days, 0:00:00
# 22          226 days, 0:00:00
# ...                       ...
# 239805       37 days, 0:00:00
# 239806       37 days, 0:00:00
# 239807       37 days, 0:00:00
# 239808       37 days, 0:00:00
# 239809       37 days, 0:00:00
#
# [16656 rows x 9 columns]
