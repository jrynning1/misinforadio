# %%
import pandas as pd
import os
import numpy as np
from pathlib import Path
from ast import literal_eval

# %%
number_return_values = 1

# %%
from openai import OpenAI
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "sk-proj-HSrHGyOHtEDtr9loLzRjT3BlbkFJTUFaqCLYDEs3B7qpBz7z"))

# %%
transcript_json = Path().cwd().parent.joinpath('data/output_json/transcript.json')

# %%
transcript_df = pd.read_json(transcript_json)

# %%
transcript_df.head(5)
# Out:
#      callsign                      file_name  \
# 0  Actualidad  Actualidad_Radio_0523_000.mp3
# 1  Actualidad  Actualidad_Radio_0523_001.mp3
# 2  Actualidad  Actualidad_Radio_0523_002.mp3
# 3  Actualidad  Actualidad_Radio_0523_003.mp3
# 4  Actualidad  Actualidad_Radio_0523_004.mp3
#
#                                        transcription
# 0  [ y y y y y y y y y y y y y y y y y cambiado d...
# 1  [ que era una campaña tanto tiempo sabiendo de...
# 2  [ Todo esto en realidad se ha convertido en un...
# 3  [ ahora en el carro se baja el carro a brazar ...
# 4  [ 3 0 5 5 5 3 5022 3 0 5 5 3 52 22 ¿Estás tu n...

# %%
exploded_transcript_df = transcript_df.explode('transcription').reset_index(drop=True)
exploded_transcript_df = exploded_transcript_df[['file_name', 'transcription']]

# %%
exploded_transcript_df
# Out:
#                           file_name  \
# 0     Actualidad_Radio_0523_000.mp3
# 1     Actualidad_Radio_0523_000.mp3
# 2     Actualidad_Radio_0523_000.mp3
# 3     Actualidad_Radio_0523_000.mp3
# 4     Actualidad_Radio_0523_000.mp3
# ...                             ...
# 6896  América_Noticias_0524_057.mp3
# 6897  América_Noticias_0524_058.mp3
# 6898  América_Noticias_0524_058.mp3
# 6899  América_Noticias_0524_058.mp3
# 6900  América_Noticias_0524_058.mp3
#
#                                           transcription
# 0      y y y y y y y y y y y y y y y y y cambiado de...
# 1     De dés breakfast, de Estado, mepolisaba una de...
# 2     unbank a Charlotte, un ayupo,ambreodies plaño,...
# 3     El último presidente que le fue bien en Nueva ...
# 4     Vamos a hablarles también de lo que está pasan...
# ...                                                 ...
# 6896  ¡El siguiente programa es una emisión previame...
# 6897                                        de la gente
# 6898  En el caso de la gente que se ha dado informat...
# 6899  Las informaciones se de Cuba a esta hora por s...
# 6900  La gente que está en la searching y que que lo...
#
# [6901 rows x 2 columns]

# %%
embedded_false_statements_path = Path().cwd().parent.joinpath('data/factchecked_statements/embedded_false_statements.csv')

# %%
false_text_df = pd.read_csv(embedded_false_statements_path)

# %%
false_text_df
# Out:
#                                          id  \
# 0      e74002af-7ca3-4071-917c-0585430d459d
# 1      64dc0acd-92c7-45fb-9255-2a5ff85cc2da
# 2      3f52fcf6-3825-4c32-b6aa-854655e70128
# 3      f953a13b-efbe-4963-84fa-c544738fb401
# 4      64dddcbd-2444-41af-8269-de7e09d3257d
# ...                                     ...
# 16024  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da
# 16025  898c10ff-db7a-4fc5-aed2-d6e72e95107f
# 16026  74d6c667-1663-49cc-b5cd-7f470b7a0006
# 16027  c56456ec-a21d-472b-904b-5201c995a3ea
# 16028  bdc63515-9536-4bce-8243-c812d0650d0b
#
#                                                   author  \
# 0      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 1      {'@type': 'Organization', 'name': 'Boatos.org'...
# 2      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 3      {'@type': 'Organization', 'name': 'Boatos.org'...
# 4      {'@type': 'Organization', 'name': 'Boatos.org'...
# ...                                                  ...
# 16024  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16025  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16026  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16027  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16028  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                                statement         rating  \
# 0      Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 1      LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 2      Líder palestino defende Israel na ONU e deixa ...          Falso
# 3      Após falência no Brasil, Pernambucanas se vê c...          Falso
# 4      Líder do Hamas, com Haddad e Gleise,Aliados?vo...          Falso
# ...                                                  ...            ...
# 16024  "OVNI en Arlington, Texas, avistado durante el...          False
# 16025  Photo shows former President Barack Obama wear...  Pants on Fire
# 16026  "OVNI en Arlington, Texas, avistado durante el...          False
# 16027  Photo shows former President Barack Obama wear...  Pants on Fire
# 16028  "OVNI en Arlington, Texas, avistado durante el...          False
#
#       datePublished  days_since_publication reformated_date  \
# 0        2023-10-19                     227      2023-10-19
# 1        2023-10-19                     227      2023-10-19
# 2        2023-10-23                     223      2023-10-23
# 3        2023-10-23                     223      2023-10-23
# 4        2023-10-19                     227      2023-10-19
# ...             ...                     ...             ...
# 16024    2024-04-25                      38      2024-04-25
# 16025    2024-04-25                      38      2024-04-25
# 16026    2024-04-25                      38      2024-04-25
# 16027    2024-04-25                      38      2024-04-25
# 16028    2024-04-25                      38      2024-04-25
#
#                                                      url  \
# 0      https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 1      https://www.boatos.org/politica/lula-aprovou-a...
# 2      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# 3      https://www.boatos.org/tecnologia/pernambucana...
# 4      https://www.boatos.org/politica/haddad-gleisi-...
# ...                                                  ...
# 16024  https://www.politifact.com/factchecks/2024/apr...
# 16025  https://www.politifact.com/factchecks/2024/apr...
# 16026  https://www.politifact.com/factchecks/2024/apr...
# 16027  https://www.politifact.com/factchecks/2024/apr...
# 16028  https://www.politifact.com/factchecks/2024/apr...
#
#       time_since_publication  \
# 0          227 days, 0:00:00
# 1          227 days, 0:00:00
# 2          223 days, 0:00:00
# 3          223 days, 0:00:00
# 4          227 days, 0:00:00
# ...                      ...
# 16024       38 days, 0:00:00
# 16025       38 days, 0:00:00
# 16026       38 days, 0:00:00
# 16027       38 days, 0:00:00
# 16028       38 days, 0:00:00
#
#                                      statement_embedding
# 0      [0.07474414259195328, -0.006695829797536135, 0...
# 1      [-0.0021664074156433344, -0.08161091804504395,...
# 2      [0.009590987116098404, -0.01076502539217472, -...
# 3      [-0.030813444405794144, 0.027191944420337677, ...
# 4      [0.011051198467612267, -0.01832002028822899, 0...
# ...                                                  ...
# 16024  [0.03281700238585472, 0.028572017326951027, -0...
# 16025  [0.017076874151825905, 0.06964606046676636, -0...
# 16026  [0.0060033719055354595, -0.007206970360130072,...
# 16027  [-0.049351081252098083, -0.02840556390583515, ...
# 16028  [0.021965298801660538, -0.015054209157824516, ...
#
# [16029 rows x 10 columns]

# %%
false_text_df['statement_embedding'] = false_text_df.statement_embedding.apply(eval).apply(np.array)

# %%
false_text_df['statement_embedding'][0]
# Out:
# array([ 0.07474414, -0.00669583,  0.00430669, ..., -0.01515349,
#         0.03986355, -0.03815511])

# %%
false_text_df['statement'] = false_text_df['statement'].replace('\'', '').replace('\"', '').replace('\"', '').replace('.','').replace('?','').replace('!','')

# %%
false_text_df
# Out:
#                                          id  \
# 0      e74002af-7ca3-4071-917c-0585430d459d
# 1      64dc0acd-92c7-45fb-9255-2a5ff85cc2da
# 2      3f52fcf6-3825-4c32-b6aa-854655e70128
# 3      f953a13b-efbe-4963-84fa-c544738fb401
# 4      64dddcbd-2444-41af-8269-de7e09d3257d
# ...                                     ...
# 16024  8fdb1f4b-9a96-4970-9ff6-275b82a7b8da
# 16025  898c10ff-db7a-4fc5-aed2-d6e72e95107f
# 16026  74d6c667-1663-49cc-b5cd-7f470b7a0006
# 16027  c56456ec-a21d-472b-904b-5201c995a3ea
# 16028  bdc63515-9536-4bce-8243-c812d0650d0b
#
#                                                   author  \
# 0      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 1      {'@type': 'Organization', 'name': 'Boatos.org'...
# 2      {'@type': 'Organization', 'name': 'Lupa', 'url...
# 3      {'@type': 'Organization', 'name': 'Boatos.org'...
# 4      {'@type': 'Organization', 'name': 'Boatos.org'...
# ...                                                  ...
# 16024  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16025  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16026  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16027  {'@type': 'Organization', 'name': 'PolitiFact'...
# 16028  {'@type': 'Organization', 'name': 'PolitiFact'...
#
#                                                statement         rating  \
# 0      Benjamin Netanyahu não atendeu Lula ao telefon...          Falso
# 1      LULA APROVA O USO DE PAU DE ARARA PRA TRANSPOR...          Falso
# 2      Líder palestino defende Israel na ONU e deixa ...          Falso
# 3      Após falência no Brasil, Pernambucanas se vê c...          Falso
# 4      Líder do Hamas, com Haddad e Gleise,Aliados?vo...          Falso
# ...                                                  ...            ...
# 16024  "OVNI en Arlington, Texas, avistado durante el...          False
# 16025  Photo shows former President Barack Obama wear...  Pants on Fire
# 16026  "OVNI en Arlington, Texas, avistado durante el...          False
# 16027  Photo shows former President Barack Obama wear...  Pants on Fire
# 16028  "OVNI en Arlington, Texas, avistado durante el...          False
#
#       datePublished  days_since_publication reformated_date  \
# 0        2023-10-19                     227      2023-10-19
# 1        2023-10-19                     227      2023-10-19
# 2        2023-10-23                     223      2023-10-23
# 3        2023-10-23                     223      2023-10-23
# 4        2023-10-19                     227      2023-10-19
# ...             ...                     ...             ...
# 16024    2024-04-25                      38      2024-04-25
# 16025    2024-04-25                      38      2024-04-25
# 16026    2024-04-25                      38      2024-04-25
# 16027    2024-04-25                      38      2024-04-25
# 16028    2024-04-25                      38      2024-04-25
#
#                                                      url  \
# 0      https://lupa.uol.com.br/jornalismo/2023/10/19/...
# 1      https://www.boatos.org/politica/lula-aprovou-a...
# 2      https://lupa.uol.com.br/jornalismo/2023/10/23/...
# 3      https://www.boatos.org/tecnologia/pernambucana...
# 4      https://www.boatos.org/politica/haddad-gleisi-...
# ...                                                  ...
# 16024  https://www.politifact.com/factchecks/2024/apr...
# 16025  https://www.politifact.com/factchecks/2024/apr...
# 16026  https://www.politifact.com/factchecks/2024/apr...
# 16027  https://www.politifact.com/factchecks/2024/apr...
# 16028  https://www.politifact.com/factchecks/2024/apr...
#
#       time_since_publication  \
# 0          227 days, 0:00:00
# 1          227 days, 0:00:00
# 2          223 days, 0:00:00
# 3          223 days, 0:00:00
# 4          227 days, 0:00:00
# ...                      ...
# 16024       38 days, 0:00:00
# 16025       38 days, 0:00:00
# 16026       38 days, 0:00:00
# 16027       38 days, 0:00:00
# 16028       38 days, 0:00:00
#
#                                      statement_embedding
# 0      [0.07474414259195328, -0.006695829797536135, 0...
# 1      [-0.0021664074156433344, -0.08161091804504395,...
# 2      [0.009590987116098404, -0.01076502539217472, -...
# 3      [-0.030813444405794144, 0.027191944420337677, ...
# 4      [0.011051198467612267, -0.01832002028822899, 0...
# ...                                                  ...
# 16024  [0.03281700238585472, 0.028572017326951027, -0...
# 16025  [0.017076874151825905, 0.06964606046676636, -0...
# 16026  [0.0060033719055354595, -0.007206970360130072,...
# 16027  [-0.049351081252098083, -0.02840556390583515, ...
# 16028  [0.021965298801660538, -0.015054209157824516, ...
#
# [16029 rows x 10 columns]

# %%
def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
# Semantic text search using embeddings, worked well, but trying to get similarity value pushed
'''
def cosine_similarity(vec1, vec2):
    # Normalize each vector to unit length
    vec1_norm = vec1 / np.linalg.norm(vec1)
    vec2_norm = vec2 / np.linalg.norm(vec2)
  
    # Calculate dot product between normalized vectors
    similarity = np.dot(vec1_norm, vec2_norm)
    return similarity

def search_false_statements(search_terms,false_text_df=false_text_df, n=1, pprint=True):
   embedding = get_embedding(search_terms, model='text-embedding-3-small')
   false_text_df['similarities'] = false_text_df.statement_embedding.apply(lambda x: cosine_similarity(x, embedding))
   results = (
      false_text_df.sort_values("similarities", ascending=False)
      .head(n).statement
   )
   if pprint:
      for r in results:
         print(r[:200])
         print()
   return results

'''
# Out:
# '\ndef cosine_similarity(vec1, vec2):\n    # Normalize each vector to unit length\n    vec1_norm = vec1 / np.linalg.norm(vec1)\n    vec2_norm = vec2 / np.linalg.norm(vec2)\n  \n    # Calculate dot product between normalized vectors\n    similarity = np.dot(vec1_norm, vec2_norm)\n    return similarity\n\ndef search_false_statements(search_terms,false_text_df=false_text_df, n=1, pprint=True):\n   embedding = get_embedding(search_terms, model=\'text-embedding-3-small\')\n   false_text_df[\'similarities\'] = false_text_df.statement_embedding.apply(lambda x: cosine_similarity(x, embedding))\n   results = (\n      false_text_df.sort_values("similarities", ascending=False)\n      .head(n).statement\n   )\n   if pprint:\n      for r in results:\n         print(r[:200])\n         print()\n   return results\n\n'

# %%
def cosine_similarity(vec1, vec2):
   # Normalize each vector to unit length
   vec1_norm = vec1 / np.linalg.norm(vec1)
   vec2_norm = vec2 / np.linalg.norm(vec2)

   # Calculate dot product between normalized vectors
   similarity = np.dot(vec1_norm, vec2_norm)
   return similarity

def search_false_statements(search_terms,false_text_df=false_text_df, n=1):
   embedding = get_embedding(search_terms, model='text-embedding-3-small')
   false_text_df['similarities'] = false_text_df.statement_embedding.apply(lambda x: cosine_similarity(x, embedding))
   results = (
      false_text_df.sort_values("similarities", ascending=False).head(n)
   )
   return results

# %%
top_matches_json = []

def search_all_transcripts():
    errors = 0
    for row in exploded_transcript_df.itertuples(name='segment'):
        match_index = row.Index
        try:
            results = search_false_statements(row.transcription)
            top_match = results.statement.values
            similarity = results.similarities
            top_matches = {}
            top_matches["index"] = f"{match_index}"
            top_matches["filename"] = row.file_name
            top_matches["input_statement"] = row.transcription
            top_matches["checked_false_statement"] = f"{top_match}"
            top_matches["similarity"] = f"{similarity}"
            top_matches_json.append(top_matches)
            print_text = f"Finished checking {match_index + 1} of {len(exploded_transcript_df)} statements -- {int((match_index + 1)/len(exploded_transcript_df)*100)}% complete         "
            print("\r", print_text, end="")
        except: 
            errors += 1
            print(f"Error checking statement {match_index + 1}")
    print(f"Finished checking all statements with {errors} error(s)")

# %%
search_all_transcripts()
# Out:
#  Finished checking 6901 of 6901 statements -- 100% complete         Finished checking all statements with 0 error(s)

# %%
top_matches_json[0]
# Out:
# {'index': '0',
#  'filename': 'Actualidad_Radio_0523_000.mp3',
#  'input_statement': ' y y y y y y y y y y y y y y y y y cambiado de masится, y sub 보면서',
#  'checked_false_statement': "['Joe Rogan spoke about a child being abducted into a secret Disneyland tunnel.']",
#  'similarity': '635    0.379565\nName: similarities, dtype: float64'}

# %%
top_matches_df = pd.DataFrame(top_matches_json)

# %%
top_matches_df['similarity_value'] = top_matches_df['similarity'].apply(lambda x: x.split()[1]).astype(float)
top_matches_df['factcheck_index'] = top_matches_df['similarity'].apply(lambda x: x.split()[0])

# %%
from libretranslatepy import LibreTranslateAPI

lt = LibreTranslateAPI("http://localhost:5000")
'''

print(lt.translate("LibreTranslate is awesome!", "en", "es"))
# LibreTranslate es impresionante!

print(lt.detect("Hello World"))
# [{"confidence": 0.6, "language": "en"}]

'''

print(lt.languages())
[{"code":"en", "name":"English"}]
# Out:
# [{'code': 'en', 'name': 'English', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'sq', 'name': 'Albanian', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'ar', 'name': 'Arabic', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'az', 'name': 'Azerbaijani', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'bn', 'name': 'Bengali', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'bg', 'name': 'Bulgarian', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'ca', 'name': 'Catalan', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'zh', 'name': 'Chinese', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'zt', 'name': 'Chinese (traditional)', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'cs', 'name': 'Czech', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'da', 'name': 'Danish', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'nl', 'name': 'Dutch', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sq', 'sv', 'th', 'tl', 'tr', 'uk', 'ur', 'zh', 'zt']}, {'code': 'eo', 'name': 'Esperanto', 'targets': ['ar', 'az', 'bg', 'bn', 'ca', 'cs', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'ga', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'ms', 'nb', 'nl', 'pl', 'pt', 'ro',  ...
# [{'code': 'en', 'name': 'English'}]

# %%
def libretranslate_spanish(input_text):
    return lt.translate(f"{input_text}", "es", "en")

def libretranslate_french(input_text):
    return lt.translate(f"{input_text}", "fr", "en")

# %%
over_50 = top_matches_df.loc[top_matches_df['similarity_value'] >= .5]

# %%
over_50['translation'] = over_50['input_statement'].apply(lambda x: libretranslate_french(x))
over_50['translation'] = over_50['translation'].apply(lambda x: libretranslate_spanish(x))
# Out:
# /tmp/ipykernel_50199/1301480557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over_50['translation'] = over_50['input_statement'].apply(lambda x: libretranslate_french(x))
# /tmp/ipykernel_50199/1301480557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over_50['translation'] = over_50['translation'].apply(lambda x: libretranslate_spanish(x))

# %%
over_50 = over_50.sort_values('similarity_value', ascending=False)

# %%
over_50 = over_50[['filename', 'input_statement', 'translation', 'checked_false_statement', 'similarity_value', 'factcheck_index']]

# %%
len(over_50)
# Out:
# 372

# %%
over_50_csv_filepath = Path().cwd().parent.joinpath('data/output_csv/potential_misinformation.csv')

# %%
print("Generating csv file...")
# Out:
# Generating csv file...

# %%
over_50.to_csv(f"{over_50_csv_filepath}")

# %%
over_50
# Out:
#                            filename  \
# 3222  América_Noticias_0524_011.mp3
# 254   Actualidad_Radio_0523_003.mp3
# 2590  América_Noticias_0524_004.mp3
# 6317  América_Noticias_0524_049.mp3
# 4037  América_Noticias_0524_020.mp3
# ...                             ...
# 5479  América_Noticias_0524_034.mp3
# 5477  América_Noticias_0524_034.mp3
# 3798  América_Noticias_0524_017.mp3
# 1254  Actualidad_Radio_0523_016.mp3
# 751   Actualidad_Radio_0523_008.mp3
#
#                                         input_statement  \
# 3222                                                 ..
# 254                                                  ..
# 2590                           Cada cáncer es diferente
# 6317                                           varios..
# 4037  Las autoridades dijeron que la combinación de ...
# ...                                                 ...
# 5479                  El órgano que elige al presidente
# 5477                  El órgano que elige al presidente
# 3798  Ya me y me redujeron la factura a solo 3.500 d...
# 1254  Yo 20 mil pasaportes a iraníes y ahora tienen ...
# 751   Vamos a continuar con el tema de lo ocurrido e...
#
#                                             translation  \
# 3222                                                  .
# 254                                                   .
# 2590                          Every cancer is different
# 6317                                        smallpox. .
# 4037  The authorities said that the combination of h...
# ...                                                 ...
# 5479                The organ that elects the president
# 5477                The organ that elects the president
# 3798           I've already been reduced to just $3,500
# 1254  I 20 thousand passports to Iranians and now th...
# 751   We will continue with the theme of what happen...
#
#                                 checked_false_statement  similarity_value  \
# 3222  ['Joe Rogan spoke about a child being abducted...          0.695436
# 254   ['Joe Rogan spoke about a child being abducted...          0.695436
# 2590  ['Pensão média na Caixa Geral de Aposentações ...          0.641937
# 6317  ['WEF is planning to add vaccines to the water...          0.641733
# 4037  ['There is a "Globalist Plan to Launch #Diseas...          0.641359
# ...                                                 ...               ...
# 5479  ['Footage shows a plane did not hit the Pentag...          0.500640
# 5477  ['Footage shows a plane did not hit the Pentag...          0.500640
# 3798  ['Jornalista da Globo chorou ao vivo após vitó...          0.500489
# 1254  ['(Video) “Las jugadoras de fútbol femenino de...          0.500225
# 751   ['Pra quem acha que o tráfico de crianças não ...          0.500180
#
#      factcheck_index
# 3222             635
# 254              635
# 2590            3195
# 6317            9417
# 4037            7379
# ...              ...
# 5479            3312
# 5477            3312
# 3798            8140
# 1254            6977
# 751             7526
#
# [372 rows x 6 columns]
